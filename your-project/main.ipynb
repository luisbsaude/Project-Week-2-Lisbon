# %%
import pandas as pd
import numpy as np

# %%
# RENT PRICES DATABASE

# %%
df_rent=pd.read_csv("../datasets/2017_lloguer_preu_trim.csv")

# %%
df_rent_colnames= ["Year","Trimester","District Code","District","Neighborhood Code",
                   "Neighborhood","Average Rent", "Price"]
df_rent.columns=df_rent_colnames
df_rent["Average Rent"]=df_rent["Average Rent"].replace("Lloguer mitjà mensual (Euros/mes)","Euros per month")
df_rent["Average Rent"]=df_rent["Average Rent"].replace("Lloguer mitjà per superfície (Euros/m2 mes)","Euros/m2 per month")

# %%
df_rent=df_rent.groupby(["District","Neighborhood","Average Rent"],as_index=False).agg({"Price":"mean"})

# %%
df_rent = df_rent.groupby(["District","Neighborhood",'Average Rent'])['Price'].mean().unstack()

# %%
df_rent=df_rent.reset_index()

# %%
df_rent
# Out:
# Average Rent             District                           Neighborhood  \
# 0                    Ciutat Vella  Sant Pere, Santa Caterina i la Ribera
# 1                    Ciutat Vella                         el Barri Gòtic
# 2                    Ciutat Vella                               el Raval
# 3                    Ciutat Vella                         la Barceloneta
# 4                        Eixample                            Sant Antoni
# ..                            ...                                    ...
# 68            Sarrià-Sant Gervasi             Sant Gervasi - la Bonanova
# 69            Sarrià-Sant Gervasi                                 Sarrià
# 70            Sarrià-Sant Gervasi  Vallvidrera, el Tibidabo i les Planes
# 71            Sarrià-Sant Gervasi                   el Putxet i el Farró
# 72            Sarrià-Sant Gervasi                        les Tres Torres
#
# Average Rent  Euros per month  Euros/m2 per month
# 0                    916.8375             15.7050
# 1                    973.7675             14.1900
# 2                    747.7150             13.8950
# 3                    746.3100             19.8450
# 4                    898.2600             12.9475
# ..                        ...                 ...
# 68                  1235.2425             15.3175
# 69                  1353.5350             17.4475
# 70                  1231.0100             16.6600
# 71                   929.1200             14.8225
# 72                  1627.2025             16.8325
#
# [73 rows x 4 columns]

# %%
# GENDER AND POPULATION DATABASE

# %%
#importing csv
df_gender_colnames = ["Year", "District code", "District name", "Neighbourhood code", "Neighbourhood name", "Gender", "Number immigrants"]
df_gender = pd.read_csv("../datasets/2017_immigrants_sexe.csv", names=df_gender_colnames, header=0)

# %%
#drop unnecessary columns
cols_to_drop = ["Year", "District code", "Neighbourhood code"]
df_gender2 = df_gender.drop(cols_to_drop, axis=1)
#df_gender
#deleting duplicate records
df_gender.drop_duplicates()
# Out:
#      Year  District code        District name  Neighbourhood code  \
# 0    2017              1         Ciutat Vella                   1
# 1    2017              1         Ciutat Vella                   2
# 2    2017              1         Ciutat Vella                   3
# 3    2017              1         Ciutat Vella                   4
# 4    2017              2             Eixample                   5
# 5    2017              2             Eixample                   6
# 6    2017              2             Eixample                   7
# 7    2017              2             Eixample                   8
# 8    2017              2             Eixample                   9
# 9    2017              2             Eixample                  10
# 10   2017              3       Sants-Montjuïc                  11
# 11   2017              3       Sants-Montjuïc                  12
# 12   2017              3       Sants-Montjuïc                  13
# 13   2017              3       Sants-Montjuïc                  14
# 14   2017              3       Sants-Montjuïc                  15
# %%
df_gender2["Gender"] = np.where((df_gender2["Gender"]=="Homes"), "Male", "Female")
df_gender2
# Out:
#     District name                     Neighbourhood name  Gender  \
# 0    Ciutat Vella                               el Raval    Male
# 1    Ciutat Vella                         el Barri Gòtic    Male
# 2    Ciutat Vella                         la Barceloneta    Male
# 3    Ciutat Vella  Sant Pere, Santa Caterina i la Ribera    Male
# 4        Eixample                          el Fort Pienc    Male
# ..            ...                                    ...     ...
# 143    Sant Martí                  el Besòs i el Maresme  Female
# 144    Sant Martí                Provençals del Poblenou  Female
# 145    Sant Martí               Sant Martí de Provençals  Female
# 146    Sant Martí                    la Verneda i la Pau  Female
# 147     No consta                              No consta  Female
#
#      Number immigrants
# 0                 3063
# 1                 1499
# 2                  910
# 3                 1438
# 4                 1082
# ..                 ...
# 143                870
# 144                505
# 145                537
# 146                638
# 147                  1
#
# [148 rows x 4 columns]

# %%
df_gender3 = pd.pivot_table(df_gender2, index="Neighbourhood name", columns="Gender", values="Number immigrants")

# %%
df_gender_last = pd.merge(df_gender2[["District name", "Neighbourhood name"]], df_gender3, on="Neighbourhood name")

df_gender_last.rename(columns={"Female":"Female immigrants", "Male":"Male immigrants"})
# Out:
#     District name        Neighbourhood name  Female immigrants  \
# 0    Ciutat Vella                  el Raval               2337
# 1    Ciutat Vella                  el Raval               2337
# 2    Ciutat Vella            el Barri Gòtic               1188
# 3    Ciutat Vella            el Barri Gòtic               1188
# 4    Ciutat Vella            la Barceloneta                849
# ..            ...                       ...                ...
# 143    Sant Martí  Sant Martí de Provençals                537
# 144    Sant Martí       la Verneda i la Pau                638
# 145    Sant Martí       la Verneda i la Pau                638
# 146     No consta                 No consta                  1
# 147     No consta                 No consta                  1
#
#      Male immigrants
# 0               3063
# 1               3063
# 2               1499
# 3               1499
# 4                910
# ..               ...
# 143              536
# 144              602
# 145              602
# 146                1
# 147                1
#
# [148 rows x 4 columns]

# %%
#importing csv
df_pop_colnames = ["Year", "District code", "District name", "Neighbourhood code", "Neighbourhood name", "Gender", "Age", "Number population"]
df_pop = pd.read_csv("../datasets/population.csv", names=df_pop_colnames, header=0)

#deleting duplicate records
df_pop.drop_duplicates()
# Out:
#        Year  District code District name  Neighbourhood code  \
# 0      2017              1  Ciutat Vella                   1
# 1      2017              1  Ciutat Vella                   2
# 2      2017              1  Ciutat Vella                   3
# 3      2017              1  Ciutat Vella                   4
# 4      2017              2      Eixample                   5
# ...     ...            ...           ...                 ...
# 70075  2013             10    Sant Martí                  69
# 70076  2013             10    Sant Martí                  70
# 70077  2013             10    Sant Martí                  71
# 70078  2013             10    Sant Martí                  72
# 70079  2013             10    Sant Martí                  73
#
#                                  Neighbourhood name  Gender   Age  \
# 0                                          el Raval    Male   0-4
# 1                                    el Barri Gòtic    Male   0-4
# 2                                    la Barceloneta    Male   0-4
# 3             Sant Pere, Santa Caterina i la Ribera    Male   0-4
# 4                                     el Fort Pienc    Male   0-4
# ...                                             ...     ...   ...
# 70075  Diagonal Mar i el Front Marítim del Poblenou  Female  >=95
# 70076                         el Besòs i el Maresme  Female  >=95
# 70077                       Provençals del Poblenou  Female  >=95
# 70078                      Sant Martí de Provençals  Female  >=95
# 70079                           la Verneda i la Pau  Female  >=95
#
#        Number population
# 0                    224
# 1                     50
# 2                     43
# 3                     95
# 4                    124
# ...                  ...
# 70075                 21
# 70076                 25
# 70077                 31
# 70078                 38
# 70079                 47
#
# [65803 rows x 8 columns]

# %%
#drop columns
cols_to_drop = ["District code", "Neighbourhood code"]
df_pop2 = df_pop.drop(cols_to_drop, axis=1)

# %%
#select records from 2017 only
df_pop2 = df_pop2[df_pop2["Year"]==2017]

# %%
#aggregate numbers by neighbourhood and gender, discarding age
df_pop3 = df_pop2.groupby(["District name", "Neighbourhood name", "Gender"], as_index=False).agg({"Number population":"sum"})

# %%
df_pop4 = pd.pivot_table(df_pop3, index=["District name","Neighbourhood name"], columns="Gender", values="Number population")

# %%
df_pop_last = pd.merge(df_pop2[["District name", "Neighbourhood name"]], df_pop4, on="Neighbourhood name")
df_pop_last=df_pop_last.rename(columns={"Female":"Female total", "Male":"Male total"})
df_pop_last=df_pop_last.drop_duplicates()
df_pop_last
# Out:
#       District name                            Neighbourhood name  \
# 0      Ciutat Vella                                      el Raval
# 192    Ciutat Vella                                el Barri Gòtic
# 384    Ciutat Vella                                la Barceloneta
# 576    Ciutat Vella         Sant Pere, Santa Caterina i la Ribera
# 768        Eixample                                 el Fort Pienc
# ...             ...                                           ...
# 13056    Sant Martí  Diagonal Mar i el Front Marítim del Poblenou
# 13248    Sant Martí                         el Besòs i el Maresme
# 13440    Sant Martí                       Provençals del Poblenou
# 13632    Sant Martí                      Sant Martí de Provençals
# 13824    Sant Martí                           la Verneda i la Pau
#
#        Female total  Male total
# 0             21806       25802
# 192            7708        8354
# 384            7541        7455
# 576           11412       11309
# 768           16962       15054
# ...             ...         ...
# 13056          6930        6699
# 13248         11395       11614
# 13440         10605        9882
# 13632         13838       12308
# 13824         15070       13621
#
# [73 rows x 4 columns]

# %%
df_total = pd.merge(df_gender_last, df_pop_last, on=["District name", "Neighbourhood name"])
df_total = df_total.drop_duplicates()
df_total
# Out:
#     District name                            Neighbourhood name  Female  Male  \
# 0    Ciutat Vella                                      el Raval    2337  3063
# 2    Ciutat Vella                                el Barri Gòtic    1188  1499
# 4    Ciutat Vella                                la Barceloneta     849   910
# 6    Ciutat Vella         Sant Pere, Santa Caterina i la Ribera    1327  1438
# 8        Eixample                                 el Fort Pienc    1155  1082
# ..            ...                                           ...     ...   ...
# 136    Sant Martí  Diagonal Mar i el Front Marítim del Poblenou     401   379
# 138    Sant Martí                         el Besòs i el Maresme     870  1146
# 140    Sant Martí                       Provençals del Poblenou     505   469
# 142    Sant Martí                      Sant Martí de Provençals     537   536
# 144    Sant Martí                           la Verneda i la Pau     638   602
#
#      Female total  Male total
# 0           21806       25802
# 2            7708        8354
# 4            7541        7455
# 6           11412       11309
# 8           16962       15054
# ..            ...         ...
# 136          6930        6699
# 138         11395       11614
# 140         10605        9882
# 142         13838       12308
# 144         15070       13621
#
# [73 rows x 6 columns]

# %%
# Immigrants by nationality

# %%
immigrants = pd.read_csv("../datasets/immigrants_by_nationality.csv")

# Checking out the table
immigrants.head()
# Out:
#    Year  District Code District Name  Neighborhood Code  \
# 0  2017              1  Ciutat Vella                  1
# 1  2017              1  Ciutat Vella                  2
# 2  2017              1  Ciutat Vella                  3
# 3  2017              1  Ciutat Vella                  4
# 4  2017              2      Eixample                  5
#
#                        Neighborhood Name Nationality  Number
# 0                               el Raval       Spain    1109
# 1                         el Barri Gòtic       Spain     482
# 2                         la Barceloneta       Spain     414
# 3  Sant Pere, Santa Caterina i la Ribera       Spain     537
# 4                          el Fort Pienc       Spain     663

# %%
# Check out the shape
immigrants.shape

# The data consists of 35k rows and 7 columns.
# Out:
# (35224, 7)

# %%
# There are no missing values in the immigrants dataset.
null_immigrants = immigrants.isnull().sum()

print(null_immigrants)
# Out:
# Year                 0
# District Code        0
# District Name        0
# Neighborhood Code    0
# Neighborhood Name    0
# Nationality          0
# Number               0
# dtype: int64

# %%
immigrants.dtypes
# Out:
# Year                  int64
# District Code         int64
# District Name        object
# Neighborhood Code     int64
# Neighborhood Name    object
# Nationality          object
# Number                int64
# dtype: object

# %%
immigrants_2 = immigrants[["Nationality"]]

immigrants_2.head()
# Out:
#   Nationality
# 0       Spain
# 1       Spain
# 2       Spain
# 3       Spain
# 4       Spain

# %%
# Checking all the Nationalities of the file

nationality = immigrants["Nationality"].value_counts()

pd.set_option("display.max_rows", 200)
print(nationality)
# Out:
# Libya                       222
# Camerun                     222
# Benin                       222
# Mozambique                  222
# Barbados                    222
# Brasil                      222
# Sri Lanka                   222
# Canada                      222
# Bulgaria                    222
# Azerbaijan                  222
# Congo                       222
# Equatorial Guinea           222
# Israel                      222
# Tanzania                    222
# Austria                     222
# Sweden                      222
# Kazakhstan                  222
# Morocco                     222
# Cyprus                      222
# Uzbekistan                  222
# Italy                       222
# Ecuador                     222
# Estonia                     222
# Iran                        222
# Mongolia                    222
# Kuwait                      222
# Argentina                   222
# Georgia                     222
# Montenegro                  222
# Andorra                     222
# Turkmenistan                222
# United States               222
# Dominican Republic          222
# Uganda                      222
# Yemen                       222
# Afghanistan                 222
# Saudi Arabia                222
# Serbia                      222
# Angola                      222
# Zimbabwe                    222
# Uruguay                     222
# Burkina Faso                222
# Malta                       222
# Venezuela                   222
# Honduras                    222
# No information              222
# Haiti                       222
# Slovakia                    222
# Mali                        222
# Hungary                     222
# Kyrgyzstan                  222
# Luxembourg                  222
# Nepal                       222
# United Kingdom              222
# Greece                      222
# Bosnia and Herzegovina      222
# Spain                       222
# Bolivia                     222
# Ivory Coast                 222
# Madagascar                  222
# South Korea                 222
# Togo                        222
# Netherlands                 222
# Slovenia                    222
# Jordan                      222
# Denmark                     222
# Thailand                    222
# Belgium                     222
# Mexico                      222
# Turkey                      222
# Armenia                     222
# Philippines                 222
# Bangladesh                  222
# Albania                     222
# Dominica                    222
# Ghana                       222
# Gabon                       222
# Nicaragua                   222
# Malaysia                    222
# Bahrain                     222
# Norway                      222
# Qatar                       222
# Iraq                        222
# Paraguay                    222
# Peru                        222
# Czech Republic              222
# Ireland                     222
# Trinidad and Tobago         222
# Oman                        222
# Russia                      222
# India                       222
# Ukraine                     222
# Maldives                    222
# Lebanon                     222
# Iceland                     222
# Nigeria                     222
# Guatemala                   222
# Australia                   222
# Guinea                      222
# Pakistan                    222
# Chile                       222
# Romania                     222
# Egypt                       222
# Mauritania                  222
# Moldova                     222
# China                       222
# New Zealand                 222
# Croatia                     222
# Gambia                      222
# El Salvador                 222
# Belarus                     222
# Kenya                       222
# Sierra Leone                222
# Lithuania                   222
# South Africa                222
# Macedonia                   222
# Latvia                      222
# Portugal                    222
# France                      222
# Panama                      222
# Singapore                   222
# Colombia                    222
# Switzerland                 222
# Sudan                       222
# Syria                       222
# Algeria                     222
# Ethiopia                    222
# Cape Verde                  222
# Germany                     222
# Finland                     222
# Senegal                     222
# Vietnam                     222
# Costa Rica                  222
# Jamaica                     222
# Guinea-Bissau               222
# Cuba                        222
# Indonesia                   222
# Tunisia                     222
# Somalia                     222
# Mauritius                   222
# Japan                       222
# Poland                      222
# United Arab Emirates        148
# Cambodja                    148
# Niger                       148
# Rwanda                      148
# Namibia                     148
# São Tomé and Príncipe       148
# Saint Kitts and Nevis       148
# Central African Republic    148
# Grenada                     148
# Burundi                     148
# State of Palestine          148
# Seychelles                  148
# Zambia                      148
# Myanmar                     148
# The Bahamas                 148
# Tajikistan                   74
# Laos                         74
# Solomon Islands              74
# Puerto Rico                  74
# Malawi                       74
# Chad                         74
# Botswana                     74
# San Marino                   74
# Antigua and Barbuda          74
# Eritrea                      74
# East Timor                   74
# Djibouti                     74
# Taiwan                       74
# North Korea                  74
# Suriname                     74
# Lesotho                      74
# Palestinian territories      74
# Guyana                       74
# Swaziland                    74
# Liberia                      74
# Name: Nationality, dtype: int64

# %%
# Checking the districts in the file
immigrants["District Name"].value_counts()
# Out:
# Nou Barris             6188
# Horta-Guinardó         5236
# Sant Martí             4760
# Sants-Montjuïc         3808
# Sant Andreu            3332
# Eixample               2856
# Sarrià-Sant Gervasi    2856
# Gràcia                 2380
# Ciutat Vella           1904
# Les Corts              1428
# No consta               476
# Name: District Name, dtype: int64

# %%
immigrants_2017 = immigrants.drop(["Year"], axis=1)
immigrants_2017.head()
# Out:
#    District Code District Name  Neighborhood Code  \
# 0              1  Ciutat Vella                  1
# 1              1  Ciutat Vella                  2
# 2              1  Ciutat Vella                  3
# 3              1  Ciutat Vella                  4
# 4              2      Eixample                  5
#
#                        Neighborhood Name Nationality  Number
# 0                               el Raval       Spain    1109
# 1                         el Barri Gòtic       Spain     482
# 2                         la Barceloneta       Spain     414
# 3  Sant Pere, Santa Caterina i la Ribera       Spain     537
# 4                          el Fort Pienc       Spain     663
